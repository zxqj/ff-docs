# %% [markdown]
# For the first iteration, the following we absolutely must define
# * `Ferret.User` - application user
# * `FantasySports.Team` - fantasy team
# * `FantasySports.League` - fantasy league
#
# because we need to show the league name and the team name.  We probably should also define
# * `FantasySports.Trade` - fantasy trade
# * `FantasySports.User` - fantasy user
# * `FantasySports.Roster` - fantasy team roster
#
#
# Though we will also need to
